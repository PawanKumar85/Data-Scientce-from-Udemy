# %% [markdown]
# ### 📘 **Student Gradebook Tracker**
#
# **Tech Stack**: Python, Pandas, Matplotlib
# **Description**:
# Built a Gradebook Tracker to manage and analyze student performance efficiently. The system allows users to input student marks for multiple subjects, calculates individual averages, assigns ranks, and visualizes grade distribution using bar and pie charts.
#
# **Features**:
#
# * ✅ Input system for multiple students and subjects
# * 📊 Computes average marks and percentage per student
# * 🏅 Ranks students based on overall performance
# * 📚 Assigns grades based on score ranges (A, B, C, etc.)
# * 📈 Visualizes:
#
#   * Subject-wise average scores (Bar Chart)
#   * Grade distribution (Pie Chart)
#
# **Skills Demonstrated**:
#
# * 🧠 Pandas DataFrame operations (creation, filtering, sorting, merging)
# * 🔁 `groupby()` and `apply()` functions for aggregation
# * 🎯 Data cleaning and formatting
# * 📉 Visualization using Matplotlib (custom bar and pie charts)
# * 🐍 Python scripting for CLI interaction

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
def assign_grade(avg):
    if avg >= 90:
        return 'A'
    elif avg >= 80:
        return 'B'
    elif avg >= 70:
        return 'C'
    elif avg >= 60:
        return 'D'
    else:
        return 'F'


with open('data.json', 'r') as file:
    data = json.load(file)

df = pd.DataFrame(data)
df['Total'] = df[['Math','Science','English']].sum(axis=1)
df['Average'] = (df['Total']/3).astype(int)
df['Grade'] = df['Average'].apply(assign_grade) 
df['Rank'] = df['Total'].rank(ascending=False,method='min').astype(int)

print("📋 Final Gradebook:\n")
df.sort_values(by='Rank')
# Out:
# 📋 Final Gradebook:
#        Name  Math  Science  English  Total  Average Grade  Rank
# 34     Isla    95       96       97    288       96     A     1
# 11    Laura    93       95       94    282       94     A     2
# 18   Sophie    94       96       92    282       94     A     2
# 4       Eva    95       92       91    278       92     A     4
# 26   Amelia    92       94       91    277       92     A     5
# 36     Kara    93       92       91    276       92     A     6
# 16    Queen    91       93       90    274       91     A     7
# 24     Yara    90       91       93    274       91     A     7
# 30     Ella    91       89       90    270       90     A     9
# 38     Maya    90       88       89    267       89     B    10
# 28    Clara    89       90       88    267       89     B    10
# 9      Judy    90       87       89    266       88     B    12
# 6     Grace    89       91       85    265       88     B    13
# ...

# %%
subject_avg = df[['Math', 'Science', 'English']].mean()
subject_avg.plot(kind='bar', title='Subject-wise Average Marks', color='skyblue')
plt.ylabel('Average Marks')
plt.tight_layout()

# %%
grade_dist = df['Grade'].value_counts()
grade_dist.plot(kind='pie', autopct='%1.1f%%', title='Grade Distribution', colors=['#4CAF50','#FFC107','#2196F3','#FF5722','#9E9E9E'])
plt.ylabel('')
plt.tight_layout()
